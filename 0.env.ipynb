# %% [markdown]
# **env creation**
#
# **1st method with anaconda**
#
# step-1
#
# conda create -n Lakshman python=3.12 -y
#
#
# step-2
#
# conda activate Lakshman

# %% [markdown]
# - 2nd method

# %% [markdown]
# step-1
#
# python -m venv venv
#
#
# step-2
#
# venv\Scripts\actiavte

# %% [markdown]
# **if you are using   linux or macos
#
# source venv/bin/actiavte
