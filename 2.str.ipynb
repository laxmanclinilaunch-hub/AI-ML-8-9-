# %% [markdown]
# **What is string ?**

# %% [markdown]
# To record any text informatiom such as names , words , pharses , sentences and paragraphs or entire encyclopedia
#
# to create the string in single or double or triple quotations

# %%
x='john'


print(x)
# Out:
# john

# %%
type(x)
# Out:
# str

# %% [markdown]
# - Why we have to prefer double quotations ratherthan single quotations

# %%
y="john"

print(y)
# Out:
# john

# %%
z='mathematical linear algebra & statistics is heart the  of machine learning & deep learning'


print(z)
# Out:
# mathematical linear algebra & statistics is heart the  of machine learning & deep learning

# %%
p='I'm pratik , i want to become a data scientist' 

print(p)
# Out:
#   Cell In[6], line 1
#     p='I'm pratik , i want to become a data scientist'
#                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
p="I'm pratik , i want to become a data scientist" 

print(p)
# Out:
# I'm pratik , i want to become a data scientist

# %% [markdown]
# - triple quotes

# %%
q= 'The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data, 
communicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights
Deploying agentic AI is not just about adopting a new tool; it requires a complete workflow transformation. Organizations must align data, put safety guardrails in place, 
and rethink how people and machines work together.
Are you looking into building your own agents or buying an agentic platform'

print(q)
# Out:
#   Cell In[8], line 1
#     q= 'The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data,
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
q= "The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data, 
communicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights
Deploying agentic AI is not just about adopting a new tool; it requires a complete workflow transformation. Organizations must align data, put safety guardrails in place, 
and rethink how people and machines work together.
Are you looking into building your own agents or buying an agentic platform"

print(q)
# Out:
#   Cell In[9], line 1
#     q= "The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data,
#                                                                                               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
q= ''' The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data, 
communicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights
Deploying agentic AI is not just about adopting a new tool; it requires a complete workflow transformation. Organizations must align data, put safety guardrails in place, 
and rethink how people and machines work together.
Are you looking into building your own agents or buying an agentic platform '''

print(q)
# Out:
#  The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data,
# communicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights
# Deploying agentic AI is not just about adopting a new tool; it requires a complete workflow transformation. Organizations must align data, put safety guardrails in place,
# and rethink how people and machines work together.
# Are you looking into building your own agents or buying an agentic platform

# %% [markdown]
# - String immutable

# %%
q.upper()
# Out:
# ' THE MAIN BENEFIT OF AGENTIC AI IS ITS ABILITY TO DRAMATICALLY LOWER "TRANSACTION COSTS"—THE TIME AND HUMAN EFFORT SPENT SEARCHING FOR DATA, \nCOMMUNICATING, AND COMPLETING ADMINISTRATIVE TASKS. BY DOING THESE STEPS AT A FRACTION OF THE COST, BUSINESSES CAN SCALE THEIR PRODUCTIVITY TO NEW HEIGHTS\nDEPLOYING AGENTIC AI IS NOT JUST ABOUT ADOPTING A NEW TOOL; IT REQUIRES A COMPLETE WORKFLOW TRANSFORMATION. ORGANIZATIONS MUST ALIGN DATA, PUT SAFETY GUARDRAILS IN PLACE, \nAND RETHINK HOW PEOPLE AND MACHINES WORK TOGETHER.\nARE YOU LOOKING INTO BUILDING YOUR OWN AGENTS OR BUYING AN AGENTIC PLATFORM '

# %%
q
# Out:
# ' The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data, \ncommunicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights\nDeploying agentic AI is not just about adopting a new tool; it requires a complete workflow transformation. Organizations must align data, put safety guardrails in place, \nand rethink how people and machines work together.\nAre you looking into building your own agents or buying an agentic platform '

# %% [markdown]
# - List mutable

# %%
a=[1,4,9]

print(a)
# Out:
# [1, 4, 9]

# %%
a.append(10)

# %%
print(a)
# Out:
# [1, 4, 9, 10]

# %% [markdown]
# - when to use print()

# %%
"ravi"

"ai&ml"

"hyderabad"
# Out:
# 'hyderabad'

# %%
print("ravi")
print("ai&ml")
print("hyderabad")
# Out:
# ravi
# ai&ml
# hyderabad

# %%
print("ravi")
print("ai&ml")
print()
print("hyderabad")
# Out:
# ravi
# ai&ml
#
# hyderabad

# %%
print("arunacham","pratik","divya",1,3,5,1.9,True,False)
# Out:
# arunacham pratik divya 1 3 5 1.9 True False

# %%
print("arunacham","pratik","divya",1,3,5,1.9,True,False, sep=" ")
# Out:
# arunacham pratik divya 1 3 5 1.9 True False

# %%
print("arunacham","pratik","divya",1,3,5,1.9,True,False,sep="CLR")
# Out:
# arunachamCLRpratikCLRdivyaCLR1CLR3CLR5CLR1.9CLRTrueCLRFalse

# %%
print("arunacham","pratik","divya",1,3,5,1.9,True,False,sep="        ")
# Out:
# arunacham        pratik        divya        1        3        5        1.9        True        False

# %%
print("ravi")
print("ai&ml")
# Out:
# ravi
# ai&ml

# %%
print("ravi",end=" ")
print("ai&ml")
# Out:
# ravi ai&ml

# %%
print("ravi",end="__")
print("ai&ml")
# Out:
# ravi__ai&ml

# %% [markdown]
# - concatenate

# %%
x="python"
y="AI&ML"
z="Genai"

print(x+y+z)
# Out:
# pythonAI&MLGenai

# %%
x=5
y="ravi"

print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 x=5
#       2 y="ravi"
#       3
# ----> 4 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x=5
y="ravi"

print(str(x) +y)
# Out:
# 5ravi

# %% [markdown]
# - Indexing

# %%
a= "datascience"

print(a)
# Out:
# datascience

# %%
print(a[4])

print(a[-7])
# Out:
# s
# s

# %%
print(a[-0])

print(a[+0])
# Out:
# d
# d

# %%
print(a[-9])
# Out:
# t

# %%
a="datascience"

print(a)
# Out:
# datascience

# %%
a[0:4]
# Out:
# 'data'

# %%
a[:]
# Out:
# 'datascience'

# %%
a[0:11]
# Out:
# 'datascience'

# %%
a[4:7]
# Out:
# 'sci'

# %%
a="datascience"

a[-11:-7]
# Out:
# 'data'

# %%
a[-7:-4]
# Out:
# 'sci'

# %% [markdown]
# - +ve slicing with step

# %%
a="datascience"

a[0:4]
# Out:
# 'data'

# %%
a[0:4:1]
# Out:
# 'data'

# %%
a[0:4:2]
# Out:
# 'dt'

# %%
a[0:4:3]
# Out:
# 'da'

# %%
a[0:4:-1]
# Out:
# ''

# %%
a[0:4:-2]
# Out:
# ''

# %%
a[-11:-7]
# Out:
# 'data'

# %%
a
# Out:
# 'datascience'

# %%
a[-11:-7:]
# Out:
# 'data'

# %%
a[-11:-7:1]
# Out:
# 'data'

# %%
a[-11:-7:2]
# Out:
# 'dt'

# %%
a[-11:-7:5]
# Out:
# 'd'

# %% [markdown]
# - len

# %%
a= "datascience"

# %%
len(a)
# Out:
# 11

# %%
b="arunachalam"

len(b)
# Out:
# 11

# %% [markdown]
# - index

# %%
b.index("r")
# Out:
# 1

# %%
b.index("m")
# Out:
# 10

# %%
b.index('a')
# Out:
# 0

# %% [markdown]
# - immutable

# %%
c="Hello"


c
# Out:
# 'Hello'

# %%
c[0]="C"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 c[0]="C"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# - replace

# %%
c.replace("H","C")
# Out:
# 'Cello'

# %%
c
# Out:
# 'Hello'

# %% [markdown]
# - lower (), upper(), capitalize(), title()

# %%
d="mathematical & linear calculas is heart of machinelearning & dEeplearning"

d
# Out:
# 'mathematical & linear calculas is heart of machinelearning & dEeplearning'

# %%
d.lower()
# Out:
# 'mathematical & linear calculas is heart of machinelearning & deeplearning'

# %%
d.upper()
# Out:
# 'MATHEMATICAL & LINEAR CALCULAS IS HEART OF MACHINELEARNING & DEEPLEARNING'

# %%
d.capitalize()
# Out:
# 'Mathematical & linear calculas is heart of machinelearning & deeplearning'

# %%
d.title()
# Out:
# 'Mathematical & Linear Calculas Is Heart Of Machinelearning & Deeplearning'

# %% [markdown]
# - Count

# %%
e="Deep Neural Networks"
e
# Out:
# 'Deep Neural Networks'

# %%
e.count("Ne")
# Out:
# 2

# %%
e.count("e")
# Out:
# 4

# %%
e.count("N")
# Out:
# 2

# %%
e.count(" ")
# Out:
# 2

# %% [markdown]
# - find

# %%
e
# Out:
# 'Deep Neural Networks'

# %%
e.find("D")
# Out:
# 0

# %%
e.find("e")
# Out:
# 1

# %%
e.find("z")
# Out:
# -1

# %% [markdown]
# - startswith / endswith

# %%
f="it is raining"

f
# Out:
# 'it is raining'

# %%
f.startswith("if")
# Out:
# False

# %%
f.startswith("it")
# Out:
# True

# %%
f.endswith("it")
# Out:
# False

# %%
f.endswith("raining")
# Out:
# True

# %% [markdown]
# - isalpha /isalnum/isdigit

# %%
g="clr"

g
# Out:
# 'clr'

# %%
g.isalpha()
# Out:
# True

# %%
g="clr7"

g.isalpha()
# Out:
# False

# %% [markdown]
# - isalnum either string or number or both

# %%
g="clr"
g.isalnum()
# Out:
# True

# %%
i="70"

i.isalnum()
# Out:
# True

# %%
g="clr7"

g.isalnum()
# Out:
# True

# %%
a="8686860563"

a.isdigit()
# Out:
# True

# %%
j="27"

j.isdigit()
# Out:
# True

# %%
g="clr7"

g.isdigit()
# Out:
# False

# %% [markdown]
# - split / join

# %%
k="who is pm of india"

k.split()
# Out:
# ['who', 'is', 'pm', 'of', 'india']

# %%
k="who is pm of india"

k.split("c")
# Out:
# ['who is pm of india']

# %%
l=['who', 'is', 'pm', 'of', 'india']


" ".join(l)
# Out:
# 'who is pm of india'

# %%
l=['who', 'is', 'pm', 'of', 'india']


"*".join(l)
# Out:
# 'who*is*pm*of*india'

# %% [markdown]
# - format

# %%
a='laxman'

# %%
print(f"this is myname:{a}")
# Out:
# this is myname:laxman

# %%
name ="laxman"
age=299

print(f" hello my name is {name} and i am {age}")
# Out:
#  hello my name is laxman and i am 299

# %%
name ="laxman"
age=299

print(f" hello my name is {name} and i am {age}")
# Out:
#  hello my name is laxman and i am 299

# %% [markdown]
# - method -2

# %%
print("Hello my name is {} and i am {}".format("laxman",299))
# Out:
# Hello my name is laxman and i am 299

# %%
print("Hello my name is {0} and i am {1}".format("laxman",299))
# Out:
# Hello my name is laxman and i am 299

# %%
print("Hello my name is {1} and i am {0}".format("laxman",299))
# Out:
# Hello my name is 299 and i am laxman
