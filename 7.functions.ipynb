# %% [markdown]
# # Function
#
# - it is a block statement that return the specific task
# - for writing about the function we have to use keyword as def
# - the purpose of function is some commonly repeatedly to do the some taks , to void the repeated tasks i,e insteading writing the same code again and again  for different inputs , we have to do with function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - # print() function also given output but the datatype is NON-TYPE
#
# - # BUT RETURN HAS GIVEN OUTPUT WITH EXACT DATATYPE

# %%
def fun():
    print("this is my function")

# %%
fun()
# Out:
# this is my function

# %%
type(fun())
# Out:
# this is my function
# NoneType

# %%
def fun1():
    return "this is my function"

# %%
fun1()
# Out:
# 'this is my function'

# %%
type(fun1())
# Out:
# str
