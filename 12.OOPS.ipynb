# %% [markdown]
# # - OOPS ?
#
# - It means object orinted programming languages
#
# - key concepts: classes, objects, attribute , method

# %% [markdown]
# # - class:
#     -  it is a blueprint for creating objects
#
#     -  it can define a set of attributes (variables) and methods (functions)  that creates object
#
#
#     -  Attributes(variables):
#         - variables holds data related to the class
#
#     -  methods (function):
#         - it can be defined within a class that operate on its attributes

# %% [markdown]
# # - Object:
#    - it is an instance of the class

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - type attributes ( variables)
#
#     -  class attribute
#     -  instance attributes
#
# - type of constructors
#     - Non -parameterized
#     - parameterized
#
#
#
# - type of method (functions)
#     - instance methods
#     - class methods
#     - static methods

# %%
class pratik:
    sub="AI&ML"      # class attribute 

    def __init__(self,name, age):     # constructor
        # instance  attributes   
        self.name =name
        self.age=age


    def find_name(self):       #  method (function)
        return self.name

    def find_age(self):        #  method
        return self.age

# %% [markdown]
# - class attribute:
#   - if we declare any variable after the classname  or before the constructor(initilization) **__ init __**  is class attributes
#
#
# - instance attribute:
#     -  if we declare any variable after construction  (initilization) **__ init __**  or above the methods with having self that is called instance variables

# %%
# initilization the values into the and declaring the my object
obj=pratik("arunachalam",25)

# %% [markdown]
# - i have to check wether the values are reaLLY initilized or not

# %%
obj.name    # accessing instance attribute
# Out:
# 'arunachalam'

# %%
obj.age     # accessing instance attribute
# Out:
# 25

# %%
obj.find_name()   # accessing of the my instance method
# Out:
# 'arunachalam'

# %%
obj.find_age()    # accessing of the my instance method
# Out:
# 25

# %%
obj.name = "rithika"     # modification of instance attribute

# %%
obj.name
# Out:
# 'rithika'

# %%
obj.age=27     # modification of instance variable

# %%
obj.age
# Out:
# 27

# %%
obj.find_name()      # modification of our instance method
# Out:
# 'rithika'

# %%
obj.find_age()             # modification of our instance method
# Out:
# 27

# %%
obj.sub                 # accessing of class attribute using object
# Out:
# 'AI&ML'

# %%
pratik.sub                # accessing of class attribute using class name
# Out:
# 'AI&ML'

# %%
obj.sub="veerapa"             # modifying of class attribute using object

# %%
obj.sub
# Out:
# 'veerapa'

# %%
pratik.sub ="likith"                # modifying of class attribute using class name

# %%
pratik.sub
# Out:
# 'likith'

# %% [markdown]
# - Type of constructor
#
# - Non-parameterized constructor:
#
#         - initilizes attributes with default values

# %%
class hotstar:
    new_show="kalki"

    def __init__(self):
        self.mail="laxman@gmail.com"
        self.password=5630                          # Non-parameterized constructor
        self.service="Free"
        self.amount=0

    def get_password(self):
        return self.password

# %%
obj=hotstar()

print(obj.get_password())
# Out:
# 5630

# %% [markdown]
# - parameterized constructor:
#   - it takes one or more arguments  in addition to self

# %%
class hotstar:
    new_show="kalki"

    def __init__(self,mail,password,service,amount):
        self.mail=mail
        self.password=password                      # parameterized constructor
        self.service=service
        self.amount=amount

    def get_password(self):
        return self.password

# %% [markdown]
# - instance method:
#    - if we are defining the method with instance variables with self as parameter , that method is called instance method

# %%
class pratik:
    sub="AI&ML"      # class attribute 

    def __init__(self,name, age):     # constructor
        # instance  attributes   
        self.name =name
        self.age=age


    def find_name(self):       # instance method (function)
        return self.name

    def find_age(self):        # instance method
        return self.age

# %%
class car():

    def __init__(self,milage,year,make, model):
        self.milage=milage
        self.year =year
        self.make=make
        self.model=model

    def car_m(self):
        print("milagw:",self.milage)    


    def car_details(self):
        print("milage",self.milage)
        print("year",self.year)
        print("model",self.model)

# %%
obj=car(25,2025,"honda",'activa250')

# %%
obj.milage
# Out:
# 25

# %%
obj.model
# Out:
# 'activa250'

# %%
obj.make
# Out:
# 'honda'

# %%
obj.year
# Out:
# 2025

# %%
obj.year=2050

obj.year
# Out:
# 2050

# %%
obj.car_details()
# Out:
# milage 25
# year 2050
# model activa250

# %%
class car1():

    def __init__(a,milage,year,make, model):
        a.milage=milage
        a.year =year
        a.make=make
        a.model=model

    def car_m(a):
        print("milagw:",a.milage)    


    def car_details(a):
        print("milage",a.milage)
        print("year",a.year)
        print("model",a.model)

# %%
my_obj=car(50,2020,"yamaha","420")

# %%
my_obj.car_details()
# Out:
# milage 50
# year 2020
# model 420

# %% [markdown]
# - class method:
#
#    - which can be defined with using the decorator @classmethod and along with you need to use cls parameter and using class variables

# %%
class netflix:
    new_show="kalki"


    def __init__(self,mail,password):
        self.mail=mail
        self.password=password
        self.service="Free"
        self.amount=0


    def get_password(self):
        return self.password


    @classmethod
    def get_newshow(cls):
        return cls.new_show


    @classmethod
    def change_newshow(cls,show_name):
        cls.new_show=show_name

# %%
netflix.get_newshow()    # accessing of class method using classname
# Out:
# 'kalki'

# %%
user=netflix("lakshman@gmail.com",1234)    # accesing class method using object

# %%
user.get_newshow()
# Out:
# 'kalki'

# %%
netflix.change_newshow("salar")
                                    # modifying of classvariable using  class nane 
print(netflix.get_newshow())
# Out:
# salar

# %%
user=netflix("lakshman@gmail.com",1234) 


user.change_newshow("kalki-2")                      # modifying of classvariable using object


user.get_newshow()
# Out:
# 'kalki-2'

# %% [markdown]
# - Static method :
#
#           - static method can be called without self or cls
#
#           - this method can access any attribute like either class attribute or instance attribute
#
#           - this can be written decorator @static method

# %%
class mymath:
    @staticmethod
    def add(x,y):
        return x+y

# %%
mymath.add(3,5)
# Out:
# 8

# %%
class netflex:

    new_show="kalki"


    def __init__(self,mail,password):
        self.mail=mail
        self.password=password
        self.service="free"
        self.amount=0



    def get_password(self):
        return self.password


    @staticmethod
    def get_newshow():
        return netflex.new_show

    
    @staticmethod
    def get_mail(instance):
        return instance.mail

# %%
user=netflex("lakshman@gmail.com",1234)

# %%
netflex.get_newshow()
# Out:
# 'kalki'

# %%
netflex.get_mail(user)
# Out:
# 'lakshman@gmail.com'

# %% [markdown]
# # - encapsulation:
#
# - it is  a pillar of oops
# - it using varibles and methods we have to controlling access to the data
#
# -  a core concept in programming where data and the functions that use that data are bundled together into a single unit
#
#
#
#
#
# - public memeber:
#
#   - it can access anywhere (inside the class or outside of the class)
#
#            - self.name=name
#
#
#
# - proteced member:
#
#
# -  the protected memeber start with one underscore
#  - it can access inside the class and its subclass ( child class)
#
#         - self._name = name
#
# - private memeber
#      - private memeber  start with duble underscore
#
#      - the private memeber can't access directly
#
#      - to access private member we have to (getter)  method and for modification use (setter) method
#
#                    - self.__name = name
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - public member

# %%
class mentor:
    def __init__(self):
        self.name="laxman"
        


obj=mentor()

print(obj.name)
# Out:
# laxman

# %% [markdown]
# - protected member

# %%
class mentor:
    def __init__(self):
        self._name='laxman'
        

obj=mentor()

print(obj._name)  # protected member
# Out:
# laxman

# %% [markdown]
# - protected member with subclasses

# %%
class father:
    def __init__(self):
        self._salary=70000




class son(father):
    def display(self):
        print(self._salary)



obj=son()


obj.display()
# Out:
# 70000

# %% [markdown]
# - private member

# %%
class mentor:
    def __init__(self):
        self.__name="laxman"



obj=mentor()

print(obj.__name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 9
#       5
#       6
#       7 obj=mentor()
#       8
# ----> 9 print(obj.__name)
#
# AttributeError: 'mentor' object has no attribute '__name'

# %% [markdown]
# - for accessing of private member we have to use getter method

# %%
class mentor:
    def __init__(self):
        self.__name="laxman"


    def get_mentorname(self):
            return self.__name


obj=mentor()

print(obj.get_mentorname())
# Out:
# laxman

# %% [markdown]
# - For modifying private data using setter method

# %%
class mentor:
    def __init__(self):
            self.__name="laxman"

    def set_mentorname(self,change):
          self.__name=change


    def get_mentorname(self):
          return  self.__name   


obj=mentor()


obj.set_mentorname("arunachalam")

print(obj.get_mentorname())
# Out:
# arunachalam

# %% [markdown]
# example

# %%
class patient:
    def __init__(self):
        self.name="arunachalam"   # public member 
        self._blood_group="A1 NEGATIVE"   # protected member 
        self.__medical_report="CANCER"     # private

    def get_medical_report(self):
        return self.__medical_report


obj=patient()


print(obj.name)   # accessing of public member
print(obj._blood_group)   # accessing of protected member
print(obj.get_medical_report())  # accessing of private member
# Out:
# arunachalam
# A1 NEGATIVE
# CANCER

# %% [markdown]
# # Abstraction
#
# - it is the process of hiding the internal implementation details and exposing only the essential functionality to the user
#
# - generally for impplementation of this using ABC and @abstractmethod

# %%
from abc import ABC,abstractmethod


class atm(ABC):
    @abstractmethod
    def withdraw_money(self, amount):
        pass


class sbi_atm(atm):

    def withdraw_money(self, amount):
        print(f"verifying account...")
        print(f"processsing of withdrawl") 
        print(f" ${amount} withdraw successfully")   



obj=sbi_atm()

obj.withdraw_money(50000)
# Out:
# verifying account...
# processsing of withdrawl
#  $50000 withdraw successfully

# %%
from abc import ABC, abstractmethod

#abstract class
class atm(ABC):


    @abstractmethod
    def withdraw(self):
        pass


#child class
class sbiatm(atm):

    def __init__(self,balance):
        self.balance=balance



    def withdraw(self):
        pin=int(input("enter pin :"))

        amount=int(input("enter the amount"))


        if pin==1234:
            if amount<=self.balance:
                self.balance-=amount
                print("transcation successful")
                print("please collect your cash") 
                print("available balance:", self.balance)

            else:
                print("insuffieent balance")
        else:
            print("invalidpin")
                   



# object
obj=sbiatm(100000)

obj.withdraw()
# Out:
# insuffieent balance

# %%
from abc import ABC, abstractmethod



class hospital(ABC):

    @abstractmethod
    def treatment(self):
        pass


class cardio(hospital):
    def treatment(self):
        print("treating heart related diseases")


class neuro(hospital):
    def treatment(self):
        print("treament related brain & nervous diseases")



obj_1=cardio() 


obj_1.treatment()
# Out:
# treating heart related diseases

# %%
obj2=neuro()

obj2.treatment()
# Out:
# treament related brain & nervous diseases

# %% [markdown]
# polymoriphsim:
#
# it is the ability of an object to take many forms
# example
#
# the single person work as different roles

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class dog:

    def sound(self):
        print("dogs barks: Bow bow")

class cat:
    def sound(self):
        print("cats meows: Meow meow")

class cow:
     def sound(self):
        print("cow moos: Moo moo")

    

obj=dog()

obj1=cat()


obj2=cow()



obj.sound()
obj1.sound()

obj2.sound()
# Out:
# dogs barks: Bow bow
# cats meows: Meow meow
# cow moos: Moo moo

# %% [markdown]
# # inheritance :
# - it acquring the properties from parents class(Base class) to child class ( derived class)
#
# - what is properties?
#
# behaviour from one class to anothers i.e means it's attributes ( variables) and methods ( functions)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - single inheritance:
#    - transfer the properties from single parent to single child

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class person():

    def __init__(self,name,idnumber):
        self.name=name
        self.idnumber=idnumber


    def details(self):
        print("my name is",self.name)
        print("my id number is ",self.idnumber) 

class employee(person):

    def __init__(self, name, idnumber,salary,post):
        person.__init__(self,name,idnumber)
                # or 
        # super().__init__(self,name,idnumber)
        self.salary=salary
        self.post=post


    def show_details(self):
        print("my name is",self.name)
        print("my id number is ",self.idnumber)
        print("my salary is ",self.salary)


# creating obj

obj=employee("pratik",6879,90000,"dentist")


obj.details()

print()

obj.show_details()
# Out:
# my name is pratik
# my id number is  6879
#
# my name is pratik
# my id number is  6879
# my salary is  90000

# %% [markdown]
# - multiple inheritance
#
#
# ![image.png](attachment:image.png)

# %%
class f:
    def __init__(self,id):
        self.id=id


    def details(self):
        print("this is my id number",self.id)



class m:
    def __init__(self,name):
        self.name=name


    def show(self):
        print("my name is ",self.name)



class child(f,m):

    def __init__(self, id,name,salary):
        f.__init__(self,id)
        m.__init__(self,name)
        self.salary=salary

    def employee_details(self):
        print('this is id number',self.id)
        print("my name is ",self.name)
        print("this is my salary",self.salary)



# creating obj
obj=child(34567,"pratik",55000)

obj.employee_details()

print()

obj.details()

print()
obj.show()
obj.details()
# Out:
# this is id number 34567
# my name is  pratik
# this is my salary 55000
#
# this is my id number 34567
#
# my name is  pratik
# this is my id number 34567
