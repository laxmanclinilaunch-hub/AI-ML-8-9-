# %% [markdown]
# - Module
#
#   - it is python file (.py)
#
#   - this file contains  functions , variables , classes that you want to include another program file
#
#
#   - for use module , we can use **import** in other file (scripts)

# %% [markdown]
# - example math_utilis.py

# %% [markdown]
# - Package:
#
#     - it a directory (folder), it contains multiple or combination of modules and having a special name ![image-2.png](attachment:image-2.png)  file
#
#
#
#
#
#
#
#     ![image.png](attachment:image.png)

# %% [markdown]
# - liabraries:
#
#    collections of modules  & packages is called "liabraries"
#
#    example :
#
#       numpy , pandas , matplot, seaborn

# %% [markdown]
# - Basic import
#    - import module_name

# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %% [markdown]
# - import with alias
#
# import module_nanme as alias

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.5 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/12.5 MB 3.2 MB/s eta 0:00:04
#    ------ --------------------------------- 2.1/12.5 MB 3.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.5 MB 3.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/12.5 MB 3.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.5 MB 3.4 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.5 MB 3.1 MB/s eta 0:00:03
#    --------------- ------------------------ 5.0/12.5 MB 3.1 MB/s eta 0:00:03
#    ------------------ --------------------- 5.8/12.5 MB 3.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.6/12.5 MB 3.2 MB/s eta 0:00:02
# ...

# %%
import numpy as np
print(np.array([1,8,5,0]))
# Out:
# [1 8 5 0]

# %% [markdown]
# - import specific function or class
#
# from module_name import function_name

# %%
from math import sqrt

sqrt(16)
# Out:
# 4.0

# %% [markdown]
# - import multiple function or classes
#     - from module_name import fun1, fun2, fun3...

# %%
from math import sqrt , pi

print(pi)

print(sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %% [markdown]
# - import all functions or classes from a module
#
#
#     - from module_name import *

# %%
from math import *


print(pi)

print(sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl (9.8 MB)
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %%
import pandas

# %%
pip install tensorflow
# Out:
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached charset_normalizer-3.4.9-cp312-cp312-win_amd64.whl.metadata (42 kB)
# ...
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ---------------------------------------- 0.0/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/350.9 MB ? eta -:--:--
#    ---------------------------------------- 2.6/350.9 MB 10.1 MB/s eta 0:00:35
#     --------------------------------------- 4.5/350.9 MB 9.6 MB/s eta 0:00:37
#     --------------------------------------- 6.8/350.9 MB 10.0 MB/s eta 0:00:35
# ...

# %%
import tensorflow as tf

# %% [markdown]
# - What is PYPI ?
#
# - PYPI - PYTHON PACKAGE INDEX ,
# - IT IS A REPOSITORY FOR PYTHON PACKAGES
# - IT allows developers to publish , share , find python liabraries and tools
#
# - PYPI HOSTS THOUSAND OF PACKAGES

# %% [markdown]
# # What is PIP ?

# %% [markdown]
# - PIP MEANS PACKAGE INSTALLER FOR PYTHON
#
# - IT IS A COMMANDLINE TOOL , USED TO INSTALL AND MANAGE PAYTHON PACKAGES FROM PYPI
