# %% [markdown]
# - list
#
# list are constructed by [ ] , and each element/ item separated by commas

# %%
metrics = ["accuracy","precision","recall","f1score","Auc_roc_curve"]

metrics
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
type(metrics)
# Out:
# list

# %% [markdown]
# - indexing +ve/ -ve

# %%
# GRAB THE 3RD element/ item


metrics[2]
# Out:
# 'recall'

# %%
# grab the last element


print(metrics[4])


print(metrics[-1])
# Out:
# Auc_roc_curve
# Auc_roc_curve

# %%
metrics
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
# grab the "p" in precision


metrics[1][0]
# Out:
# 'p'

# %%
# grab the "pre" in precision


metrics[1][0:3]
# Out:
# 'pre'

# %% [markdown]
# - slicing +ve/ -ve

# %%
metrics = ["accuracy","precision","recall","f1score","Auc_roc_curve"]

metrics
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[ : ]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[0 : ]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[ : 5]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[ 0: 5]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[ : : ]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[ 0: : ]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[ :5 : ]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[ : : 1]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[ 0:5 : 1]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[ : : 2]
# Out:
# ['accuracy', 'recall', 'Auc_roc_curve']

# %%
metrics[0:5:1]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'Auc_roc_curve']

# %%
metrics[0:5:2]
# Out:
# ['accuracy', 'recall', 'Auc_roc_curve']

# %%
metrics[0:5:-2]
# Out:
# []

# %%
metrics[-1:-5:-2]
# Out:
# ['Auc_roc_curve', 'recall']

# %%
metrics[0:5:-2]
# Out:
# []

# %% [markdown]
# - methods / functions

# %% [markdown]
# - len

# %%
metrics = ["accuracy","precision","recall","f1score","Auc_roc_curve"]


len(metrics)
# Out:
# 5

# %%
a="python"

len(a)
# Out:
# 6

# %% [markdown]
# - min / max/ sum

# %%
b=[1,2,3,3,99,13,6,4,7,323,2,1]



print(min(b))

print(max(b))


print(sum(b))
# Out:
# 1
# 323
# 464

# %%
c=["a","b","z",'y']


print(min(c))


print(max(c))
# Out:
# a
# z

# %%
d=["a","b","z","B","Y"]


print(min(d))

print(max(d))
# Out:
# B
# z

# %% [markdown]
# - sorted -- function

# %%
e=[1,2,3,4,2,3,5,15,7,3,47,0]


sorted(e)
# Out:
# [0, 1, 2, 2, 3, 3, 3, 4, 5, 7, 15, 47]

# %%
sorted(e,reverse=True)
# Out:
# [47, 15, 7, 5, 4, 3, 3, 3, 2, 2, 1, 0]

# %% [markdown]
# - methods

# %% [markdown]
# - append/ extend/ insert

# %%
f=[1,2,5,"pratik","divya",'arunachalam']

f
# Out:
# [1, 2, 5, 'pratik', 'divya', 'arunachalam']

# %% [markdown]
# - Append
#
# - you can  add at the end of list and you can one item once

# %%
f.append("anisha")

# %%
f
# Out:
# [1, 2, 5, 'pratik', 'divya', 'arunachalam', 'anisha']

# %% [markdown]
# - extend

# %%
f
# Out:
# [1, 2, 5, 'pratik', 'divya', 'arunachalam', 'anisha']

# %%
f.extend(['python',"sql",'ml','dl','cv',"genai"])

# %%
f
# Out:
# [1,
#  2,
#  5,
#  'pratik',
#  'divya',
#  'arunachalam',
#  'anisha',
#  'python',
#  'sql',
#  'ml',
#  'dl',
#  'cv',
#  'genai']

# %% [markdown]
# - insert

# %%
f.insert(0,'MLOPS')

# %%
f
# Out:
# ['MLOPS',
#  1,
#  2,
#  5,
#  'pratik',
#  'divya',
#  'arunachalam',
#  'anisha',
#  'python',
#  'sql',
#  'ml',
#  'dl',
#  'cv',
#  'genai']

# %% [markdown]
# - pop / remove / del / clear

# %%
f
# Out:
# ['MLOPS',
#  1,
#  2,
#  5,
#  'pratik',
#  'divya',
#  'arunachalam',
#  'anisha',
#  'python',
#  'sql',
#  'ml',
#  'dl',
#  'cv',
#  'genai']

# %% [markdown]
# - pop

# %%
f.pop()
# Out:
# 'genai'

# %%
f
# Out:
# ['MLOPS',
#  1,
#  2,
#  5,
#  'pratik',
#  'divya',
#  'arunachalam',
#  'anisha',
#  'python',
#  'sql',
#  'ml',
#  'dl',
#  'cv']

# %%
f.pop(1)
# Out:
# 1

# %%
f
# Out:
# ['MLOPS',
#  2,
#  5,
#  'pratik',
#  'divya',
#  'arunachalam',
#  'anisha',
#  'python',
#  'sql',
#  'ml',
#  'dl',
#  'cv']

# %% [markdown]
# - remove

# %%
f.remove(2)

# %%
f
# Out:
# ['MLOPS',
#  5,
#  'pratik',
#  'divya',
#  'arunachalam',
#  'anisha',
#  'python',
#  'sql',
#  'ml',
#  'dl',
#  'cv']

# %%
del f[1]

f
# Out:
# ['MLOPS',
#  'pratik',
#  'divya',
#  'arunachalam',
#  'anisha',
#  'python',
#  'sql',
#  'ml',
#  'dl',
#  'cv']

# %%
f.clear()

# %%
f
# Out:
# []

# %%
del f

# %%
f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 f
#
# NameError: name 'f' is not defined

# %% [markdown]
# - count

# %%
e=[1,2,3,4,2,3,5,15,7,3,47,0]


e.count(3)
# Out:
# 3

# %% [markdown]
# - index

# %%
e.index(47)
# Out:
# 10

# %%
e.index(2)
# Out:
# 1

# %% [markdown]
# - sort method

# %%
e
# Out:
# [1, 2, 3, 4, 2, 3, 5, 15, 7, 3, 47, 0]

# %%
e.sort()

e
# Out:
# [0, 1, 2, 2, 3, 3, 3, 4, 5, 7, 15, 47]

# %%
e.sort(reverse=True)
e
# Out:
# [47, 15, 7, 5, 4, 3, 3, 3, 2, 2, 1, 0]
