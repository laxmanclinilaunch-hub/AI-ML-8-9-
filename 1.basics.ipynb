# %%
9
# Out:
# 9

# %%
a=9
print(a)
# Out:
# 9

# %%
_a=9

print(_a)
# Out:
# 9

# %%
7a=6
print(7a)
# Out:
#   Cell In[5], line 1
#     7a=6
#     ^
# SyntaxError: invalid decimal literal

# %%
7_a=6
print(7_a)
# Out:
#   Cell In[6], line 1
#     7_a=6
#      ^
# SyntaxError: invalid decimal literal

# %%
a_8=9

print(a_8)
# Out:
# 9

# %%
_a8=0

print(_a8)
# Out:
# 0

# %%
BD=143

print(bd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 BD=143
#       2
# ----> 3 print(bd)
#
# NameError: name 'bd' is not defined

# %%
bf=45

print(BF)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 bf=45
#       2
# ----> 3 print(BF)
#
# NameError: name 'BF' is not defined

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
True=8

print(True)
# Out:
#   Cell In[13], line 1
#     True=8
#     ^
# SyntaxError: cannot assign to True

# %% [markdown]
# - Operators
#
# **Arithmetic operators**

# %%
2+5
# Out:
# 7

# %%
3-1
# Out:
# 2

# %%
2*3
# Out:
# 6

# %%
# division   gives output in float  
 
3/2
# Out:
# 1.5

# %%
25/5
# Out:
# 5.0

# %%
# Floor divion gives output in integer

print("divion",3/2)

print("floor divion",3//2)


print("diviosion",3/4)
print("floor divion",3//4)


print("divion",4/5)
print("floor divion",4//5)
# Out:
# divion 1.5
# floor divion 1
# diviosion 0.75
# floor divion 0
# divion 0.8
# floor divion 0

# %%
y=5
x=3

z=y%x
print(z)
# Out:
# 2

# %%
7%6
# Out:
# 1

# %%
2**2
# Out:
# 4

# %%
2**3
# Out:
# 8

# %% [markdown]
# - Assignment operators

# %%
salary =50000

salary +=5000
print(salary)


salary -=2000

print("after tax",salary)




salary *=2

print("two months salary after tax:", salary)


salary /=2

print("one month salary after tax:", salary)
# Out:
# 55000
# after tax 53000
# two months salary after tax: 106000
# one month salary after tax: 53000.0

# %%
salary =50000

salary +=5000

salary
# Out:
# 55000

# %%
salary =50000

salary =salary +6000

print(salary)
# Out:
# 56000

# %%
salary =50000

salary =salary -3000
print(salary)
# Out:
# 47000

# %%
x=5
y=3
z=7

print(x)
print(y)
print(z)
# Out:
# 5
# 3
# 7

# %%
x ,y ,z= 5,3,7
print(x)
print(y)
print(z)
# Out:
# 5
# 3
# 7

# %%
fruits=["apple","banana","mango","grapes"]

p,q,r,s=fruits

print(p)
print(q)
print(r)
print(s)
# Out:
# apple
# banana
# mango
# grapes

# %% [markdown]
# - Comparision operator

# %%
1>5
# Out:
# False

# %%
2<5
# Out:
# True

# %%
2>7
# Out:
# False

# %%
2==7
# Out:
# False

# %%
True>0
# Out:
# True

# %%
True==1
# Out:
# True

# %%
False==0
# Out:
# True

# %%
True>False
# Out:
# True

# %%
7!=9
# Out:
# True

# %%
2>=3
# Out:
# False

# %%
2<=3
# Out:
# True

# %% [markdown]
# - logical operators

# %% [markdown]
# - and

# %%
x=50
print(x)
# Out:
# 50

# %%
x<6  and  x<10       #False and false = False
# Out:
# False

# %%
x>6 and x<10    # True and Flase = False
# Out:
# False

# %%
x>6  and  x>10   #true and true = True
# Out:
# True

# %% [markdown]
# - or

# %%
x>6 or x>10   # True or True = True
# Out:
# True

# %%
x>6 or x<10  # true or false = True
# Out:
# True

# %%
x<6 or x<10    # False or False = False
# Out:
# False

# %% [markdown]
# - not

# %%
x>6 or x<10
# Out:
# True

# %%
not (x>6 or x<10 )
# Out:
# False

# %%
x<6 or x<10
# Out:
# False

# %%
not (x<6 or x<10 )
# Out:
# True

# %% [markdown]
# - membership operators  (in ,not in)

# %%
y =[3,4,5,6, "divya", "pratik",'arunachalam', 3+8j, 0.5 ]

print(9 in y)


print(9 not in y)

print("divya" in y)

print("pratik" not in y)
# Out:
# False
# True
# True
# False
